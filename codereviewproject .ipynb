# %%
# !find /kaggle/input
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/do7amo7amed
# /kaggle/input/datasets/do7amo7amed/codereviewtipsproject
# /kaggle/input/datasets/do7amo7amed/codereviewtipsproject/app.py
# /kaggle/input/datasets/do7amo7amed/codereviewtipsproject/backend.py

# %%
# !pip install pyngrok
# !pip install -q streamlit pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 66.1 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 28.4 MB/s eta 0:00:0000:0100:01

# %%
import streamlit
print(streamlit.__version__)
# Out:
# 1.60.0

# %%
# !pip install -q langchain langchain-community langchain-huggingface

# !pip install transformers==4.52.4  langchain-classic

# !pip install -q sentence-transformers faiss-cpu
# !pip install -q bitsandbytes accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.1 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.6/561.6 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3HAqQ8A0DL4MpJ7aAgJZOP2eJE5_PA9q5uh6SE6u75vYTLs4")

# %%
APP = "/kaggle/input/datasets/do7amo7amed/codereviewtipsproject/app.py"

# %%
import subprocess

process = subprocess.Popen(
    ["streamlit", "run", APP, "--server.port", "8051"]
)

# %%
public_url = ngrok.connect(8051)

print(public_url)
# Out:
# ...
#
# NgrokTunnel: "https://urban-fit-scuba.ngrok-free.dev" -> "http://localhost:8051"

# %%
# !ps -ef | grep streamlit
# Out:
# root         155      58  0 15:04 ?        00:00:00 /usr/bin/python3 /usr/local/bin/streamlit run /kaggle/input/datasets/do7amo7amed/codereviewtipsproject/app.py --server.port 8051
# root         173      58  0 15:04 pts/0    00:00:00 /bin/bash -c ps -ef | grep streamlit
# root         175     173  0 15:04 pts/0    00:00:00 grep streamlit

# %%
# !streamlit run /kaggle/input/datasets/do7amo7amed/codereviewtipsproject/app.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8051
#   Network URL: http://172.19.2.2:8051
#   External URL: http://34.67.157.111:8051
# 2026-07-29 15:04:06.923 Uvicorn server started on :::8051
# 2026-07-29 15:04:07.502 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.19.2.2:8501
#   External URL: http://34.67.157.111:8501
#
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   129 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:807 in code_to_exec
# ...
